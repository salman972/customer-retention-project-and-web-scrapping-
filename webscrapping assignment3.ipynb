# %% [markdown]
# 1. Write a python program which searches all the product under a particular product vertical
# from www.amazon.in. The product verticals to be searched will be taken as input from user.
# For e.g. If user input is ‘guitar’. Then search for guitars

# %%
import selenium
from selenium import webdriver
import time

# %%
#loading amazon website
driver=webdriver.Chrome(r"chromedriver.exe")
url='https://www.amazon.in/'
driver.get(url)

# %%
user_input=input("Enter product you want to search: ")
# Out:
# Enter product you want to search: guitar

# %%
searchinput=driver.find_element_by_id("twotabsearchtextbox")
searchinput.clear()
searchinput.send_keys(user_input)
searchbtn=driver.find_element_by_id("nav-search-submit-button")
searchbtn.click()

# %% [markdown]
# 2. In the above question, now scrape the following details of each product listed in first 3 pages
# of your search results and save it in a dataframe and csv. In case if any product vertical has
# less than 3 pages in search results then scrape all the products available under that product
# vertical. Details to be scraped are: "Brand Name", "Name of the Product", "Rating", "No. of
# Ratings", "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details"
# and “Product URL”. In case, if any of the details are missing for any of the product then
# replace it by “-“

# %%
from selenium.common.exceptions import NoSuchElementException

# %%
#fetching url of 3 pages
urls=[]
for i in range(0,3):
    for i in driver.find_elements_by_xpath("//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-4']/a"):
        urls.append(i.get_attribute("href"))
    driver.find_element_by_xpath("//li[@class='a-last']").click()
    time.sleep(4)

# %%
url1=urls[0:100]

# %%
brandname=[]
productname=[]
rating=[]
numberrating=[]
price=[]
exchange=[]
expected=[]
availability=[]
url=[]
for i in url1:
    driver.get(i)
    time.sleep(5)
    try:
        brandname.append(driver.find_element_by_xpath("//table[@class='a-keyvalue prodDetTable']/tbody/tr[10]").text)
    except NoSuchElementException:
        brandname.append('-')
    try:
        productname.append(driver.find_element_by_xpath("//h1[@class='a-size-large a-spacing-none']").text)
    except NoSuchElementException:
        productname.append('-')
    try:
        rating.append(driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']").text)
    except NoSuchElementException:
        rating.append('-')
    try:
        numberrating.append(driver.find_element_by_id("acrCustomerReviewText").text)
    except NoSuchElementException:
        numberrating.append('-')
    try:
        price.append(driver.find_element_by_xpath("//span[@class='a-size-medium a-color-price priceBlockBuyingPriceString']").text)
    except NoSuchElementException:
        price.append('-')
    try:
        exchange.append(driver.find_element_by_xpath("//a[@class='a-size-small a-link-normal a-text-normal']").text)
    except NoSuchElementException:
        exchange.append("-")
    try:
        expected.append(driver.find_element_by_xpath("//div[@class='a-section a-spacing-mini']/b").text)
    except NoSuchElementException:
        expected.append('-')
    try:
        availability.append(driver.find_element_by_xpath("//span[@class='a-size-medium a-color-success']").text)
    except NoSuchElementException:
        availability.append('-')
    url.append(i)

# %%
import pandas as pd
df=pd.DataFrame({})
df['brandname']=brandname
df['productname']=productname
df['rating']=rating
df['numberrating']=numberrating
df['price']=price
df['exchange']=exchange
df['expected']=expected
df['availability']=availability
df['url']=url
df
# Out:
#                                       brandname  \
# 0                          Manufacturer Kadence
# 1                          Manufacturer Kadence
# 2                          Manufacturer Kadence
# 3                           Manufacturer Juârez
# 4                           Manufacturer Juârez
# ..                                          ...
# 95                      Country of Origin China
# 96                         Manufacturer Kadence
# 97                       Item Weight 2 kg 460 g
# 98  Material Bass Wood, Rosewood, Mahogany Wood
# 99              Neck Material Type Catalpa Wood
#
#                                           productname        rating  \
# 0   Kadence Frontier Jumbo Semi Acoustic Guitar Wi...  3.9 out of 5
# 1   Kadence Frontier Series,Blue Acoustic Guitar W...    4 out of 5
# 2   Kadence Slowhand Premium Jumbo Size Semi Acous...  4.3 out of 5
# 3   Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...  3.9 out of 5
# 4   Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...  3.9 out of 5
# ..                                                ...           ...
# 95  Martin Smith W-101-WHT-PK Acoustic Guitar Supe...  3.3 out of 5
# 96  Kadence Frontier Series,Blue Acoustic Guitar W...    4 out of 5
# 97  JUAREZ Belleza 39 Inch Acoustic Guitar Kit, Li...  3.5 out of 5
# 98  Blueberry B-40, 40" Acoustic Guitar Kit with B...    1 out of 5
# 99  Belear I-280 Couturier Series 38 Inch TBS Cuta...             -
#
#      numberrating       price            exchange           expected  \
# 0     431 ratings  ₹ 5,999.00  7 Days Replacement                  -
# 1     235 ratings           -  7 Days Replacement                  -
# 2     122 ratings           -  7 Days Replacement                  -
# 3   9,448 ratings           -  7 Days Replacement  Thursday, June 10
# 4   9,448 ratings           -  7 Days Replacement  Thursday, June 10
# ..            ...         ...                 ...                ...
# 95     13 ratings  ₹ 5,269.00  7 Days Replacement  Thursday, June 10
# 96    235 ratings           -  7 Days Replacement                  -
# 97      3 ratings  ₹ 5,499.00  7 Days Replacement  Thursday, June 10
# 98       1 rating  ₹ 3,595.00  7 Days Replacement                  -
# 99              -  ₹ 2,399.00  7 Days Replacement        June 4 - 14
#
#    availability                                                url
# 0     In stock.  https://www.amazon.in/gp/slredirect/picassoRed...
# 1     In stock.  https://www.amazon.in/gp/slredirect/picassoRed...
# 2     In stock.  https://www.amazon.in/gp/slredirect/picassoRed...
# 3     In stock.  https://www.amazon.in/gp/slredirect/picassoRed...
# 4     In stock.  https://www.amazon.in/Juarez-Acoustic-Cutaway-...
# ..          ...                                                ...
# 95    In stock.  https://www.amazon.in/Martin-Smith-W-101-WHT-P...
# 96    In stock.  https://www.amazon.in/Kadence-Frontier-Acousti...
# 97    In stock.  https://www.amazon.in/JUAREZ-Acoustic-Rosewood...
# 98    In stock.  https://www.amazon.in/Blueberry-Acoustic-Guita...
# 99            -  https://www.amazon.in/Belear-I-280-Couturier-C...
#
# [100 rows x 9 columns]

# %%
df['brandname']=df['brandname'].apply(lambda x:x.replace('Manufacturer',''))
df['rating']=df['rating'].apply(lambda x:x.split(' ')[0])
df['numberrating']=df['numberrating'].apply(lambda x:x.split(' ')[0])
df
# Out:
#                                       brandname  \
# 0                                       Kadence
# 1                                       Kadence
# 2                                       Kadence
# 3                                        Juârez
# 4                                        Juârez
# ..                                          ...
# 95                      Country of Origin China
# 96                                      Kadence
# 97                       Item Weight 2 kg 460 g
# 98  Material Bass Wood, Rosewood, Mahogany Wood
# 99              Neck Material Type Catalpa Wood
#
#                                           productname rating numberrating  \
# 0   Kadence Frontier Jumbo Semi Acoustic Guitar Wi...    3.9          431
# 1   Kadence Frontier Series,Blue Acoustic Guitar W...      4          235
# 2   Kadence Slowhand Premium Jumbo Size Semi Acous...    4.3          122
# 3   Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...    3.9        9,448
# 4   Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...    3.9        9,448
# ..                                                ...    ...          ...
# 95  Martin Smith W-101-WHT-PK Acoustic Guitar Supe...    3.3           13
# 96  Kadence Frontier Series,Blue Acoustic Guitar W...      4          235
# 97  JUAREZ Belleza 39 Inch Acoustic Guitar Kit, Li...    3.5            3
# 98  Blueberry B-40, 40" Acoustic Guitar Kit with B...      1            1
# 99  Belear I-280 Couturier Series 38 Inch TBS Cuta...      -            -
#
#          price            exchange           expected availability  \
# 0   ₹ 5,999.00  7 Days Replacement                  -    In stock.
# 1            -  7 Days Replacement                  -    In stock.
# 2            -  7 Days Replacement                  -    In stock.
# 3            -  7 Days Replacement  Thursday, June 10    In stock.
# 4            -  7 Days Replacement  Thursday, June 10    In stock.
# ..         ...                 ...                ...          ...
# 95  ₹ 5,269.00  7 Days Replacement  Thursday, June 10    In stock.
# 96           -  7 Days Replacement                  -    In stock.
# 97  ₹ 5,499.00  7 Days Replacement  Thursday, June 10    In stock.
# 98  ₹ 3,595.00  7 Days Replacement                  -    In stock.
# 99  ₹ 2,399.00  7 Days Replacement        June 4 - 14            -
#
#                                                   url
# 0   https://www.amazon.in/gp/slredirect/picassoRed...
# 1   https://www.amazon.in/gp/slredirect/picassoRed...
# 2   https://www.amazon.in/gp/slredirect/picassoRed...
# 3   https://www.amazon.in/gp/slredirect/picassoRed...
# 4   https://www.amazon.in/Juarez-Acoustic-Cutaway-...
# ..                                                ...
# 95  https://www.amazon.in/Martin-Smith-W-101-WHT-P...
# 96  https://www.amazon.in/Kadence-Frontier-Acousti...
# 97  https://www.amazon.in/JUAREZ-Acoustic-Rosewood...
# 98  https://www.amazon.in/Blueberry-Acoustic-Guita...
# 99  https://www.amazon.in/Belear-I-280-Couturier-C...
#
# [100 rows x 9 columns]

# %% [markdown]
# 3. Write a python program to access the search bar and search button on images.google.com and
# scrape 100 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’.

# %%
import selenium
from selenium import webdriver
import pandas as pd
import time

# %%
driver=webdriver.Chrome(r'chromedriver.exe')
url='https://images.google.com/?gws_rd=ssl'
driver.get(url)
time.sleep(3)

# %%
input1=driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")
input1.send_keys("fruits")
driver.find_element_by_xpath("//button[@class='Tg7LZd']").click()

# %%
for i in range(1000):
    driver.execute_script("window.scrollBy(0,10000)")

# %%
fruit_url=[]
for i in driver.find_elements_by_xpath("//div[@class='bRMDJf islir']/img"):
        x=i.get_attribute("src")
        if x is not None:
            if(x[0:4] == 'http'):
                fruit_url.append(x)

# %%
driver.find_element_by_xpath("//input[@class='og3lId']").clear()
driver.find_element_by_xpath("//input[@class='og3lId']").send_keys("cars")

# %%
driver.find_element_by_xpath("//div[@class='XZ5MVe']").click()

# %%
for i in range(1000):
    driver.execute_script("window.scrollBy(0,10000)")

# %%
car_url=[]
for i in driver.find_elements_by_xpath("//div[@class='bRMDJf islir']/img"):
        x=i.get_attribute("src")
        if x is not None:
            if(x[0:4] == 'http'):
                car_url.append(x)

# %%
driver.find_element_by_xpath("//input[@class='og3lId']").clear()
driver.find_element_by_xpath("//input[@class='og3lId']").send_keys("machine learning")
driver.find_element_by_xpath("//span[@class='n6h3Rc']").click()

# %%
for i in range(1000):
    driver.execute_script("window.scrollBy(0,10000)")

# %%
ml_url=[]
for i in driver.find_elements_by_xpath("//div[@class='bRMDJf islir']/img"):
    x=i.get_attribute("src")
    if x is not None:
        if(x[0:4]=='http'):
            ml_url.append(x)

# %%
df=pd.DataFrame({})
df['Fruits']=fruit_url[0:100]
df['Cars']=car_url[0:100]
df['Machine learning']=ml_url[0:100]
df
# Out:
#                                                Fruits  \
# 0   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4   https://encrypted-tbn0.gstatic.com/images?q=tb...
# ..                                                ...
# 95  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 96  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 97  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 98  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 99  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                                  Cars  \
# 0   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4   https://encrypted-tbn0.gstatic.com/images?q=tb...
# ..                                                ...
# 95  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 96  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 97  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 98  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 99  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                      Machine learning
# 0   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4   https://encrypted-tbn0.gstatic.com/images?q=tb...
# ..                                                ...
# 95  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 96  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 97  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 98  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 99  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
# [100 rows x 3 columns]

# %% [markdown]
# 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on
# www.flipkart.com and scrape following details for all the search results displayed on 1st page.
# Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”,
# “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Display
# Resolution”, “Processor”, “Processor Cores”, “Battery Capacity”, “Price”, “Product URL”.
# Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe
# and CSV.

# %%
import selenium
from selenium import webdriver
import pandas as pd
import time

# %%
driver=webdriver.Chrome(r'chromedriver.exe')
driver.get("https://www.flipkart.com/")

# %%
driver.find_element_by_xpath("//button[@class='_2KpZ6l _2doB4z']").click()
driver.find_element_by_xpath("//input[@class='_3704LK']").send_keys("pixel 4A")
driver.find_element_by_xpath("//button[@class='L0Z3Pu']").click()

# %%
urls=[]
for i in driver.find_elements_by_xpath("//a[@class='_1fQZEK']"):
    urls.append(i.get_attribute("href"))

# %%
from selenium.common.exceptions import NoSuchElementException

# %%
smartphonename=[]
color=[]
ram=[]
rom=[]
displaysize=[]
displayresolution=[]
primarycamera=[]
secondarycamera=[]
processor=[]
processorcore=[]
battery=[]
price=[]
url=[]
for i in urls:
    driver.get(i)
    time.sleep(5)
    driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    time.sleep(5)
    try:
        smartphonename.append(driver.find_element_by_xpath("//span[@class='B_NuCI']").text)
    except NoSuchElementException:
        smartphonename.append('-')
    try:
        color.append(driver.find_element_by_xpath("//div[@class='_3k-BhJ']/table/tbody/tr[4]/td[2]").text)
    except NoSuchElementException:
        color.append('-')
    try:
        ram.append(driver.find_element_by_xpath("//div[@class='_1UhVsV']/div[4]/table/tbody/tr[2]/td[2]").text)
    except NoSuchElementException:
        ram.append('-')
    try:
        rom.append(driver.find_element_by_xpath("//div[@class='_1UhVsV']/div[4]/table/tbody/tr[1]/td[2]").text)
    except NoSuchElementException:
        rom.append('-')
    try:
        displaysize.append(driver.find_element_by_xpath("//div[@class='_1UhVsV']/div[2]/table/tbody/tr/td[2]").text)
    except NoSuchElementException:
        displaysize.append('-')
    try:
        primarycamera.append(driver.find_element_by_xpath("//div[@class='_3k-BhJ'][5]/table/tbody/tr[2]/td[2]").text)
    except NoSuchElementException:
        primarycamera.append('-')
    try:
        secondarycamera.append(driver.find_element_by_xpath("//div[@class='_3k-BhJ'][5]/table/tbody/tr[5]/td[2]").text)
    except NoSuchElementException:
        secondarycamera.append('-')
    try:
        displayresolution.append(driver.find_element_by_xpath("//div[@class='_3k-BhJ'][2]/table/tbody/tr[2]/td[2]").text)
    except NoSuchElementException:
        displayresolution.append('-')
    try:
        processor.append(driver.find_element_by_xpath("//div[@class='_3k-BhJ'][3]/table/tbody/tr[2]/td[2]").text)
    except NoSuchElementException:
        processor.append('-')
    try:
        processorcore.append(driver.find_element_by_xpath("//div[@class='_3k-BhJ'][3]/table/tbody/tr[3]/td[2]").text)
    except NoSuchElementException:
        processorcore.append('-')
    try:
        battery.append(driver.find_element_by_xpath("//div[@class='_3k-BhJ'][9]/table/tbody/tr/td[2]").text)
    except NoSuchElementException:
        battery.append('-')
    try:
        price.append(driver.find_element_by_xpath("//div[@class='_30jeq3 _16Jk6d']").text)
    except NoSuchElementException:
        price.append('-')
    url.append(i)

# %%
df=pd.DataFrame({})
df['smartphonename']=smartphonename
df['color']=color
df['ram']=ram
df['rom']=rom
df['displaysize']=displaysize
df['displayresolution']=displayresolution
df['primarycamera']=primarycamera
df['secondarycamera']=secondarycamera
df['processor']=processor
df['processorcore']=processorcore
df['battery']=battery
df['price']=price
df['url']=url
df
# Out:
#                                        smartphonename            color   ram  \
# 0    Google Pixel 4a (Just Black, 128 GB)  (6 GB RAM)       Just Black  6 GB
# 1   REDMI 9 Power (Electric Green, 64 GB)  (4 GB RAM)   Electric Green  4 GB
# 2     REDMI 9 Power (Mighty Black, 64 GB)  (4 GB RAM)     Mighty Black  4 GB
# 3       REDMI Note 9 (Pebble Grey, 64 GB)  (4 GB RAM)      Pebble Grey  4 GB
# 4     REDMI 9 Power (Blazing Blue, 64 GB)  (4 GB RAM)     Blazing Blue  4 GB
# 5        REDMI 9 Power (Fiery Red, 64 GB)  (4 GB RAM)        Fiery Red  4 GB
# 6      REDMI Note 9 (Shadow Black, 64 GB)  (4 GB RAM)     Shadow Black  4 GB
# 7        REDMI Note 9 (Aqua Green, 64 GB)  (4 GB RAM)       Aqua Green  4 GB
# 8   SAMSUNG Galaxy M31 (Space Black, 128 GB)  (6 G...      Space Black  6 GB
# 9          Redmi 9 (Sporty Orange, 64 GB)  (4 GB RAM)    Sporty Orange  4 GB
# 10          Redmi 9 (Carbon Black, 64 GB)  (4 GB RAM)     Carbon Black  4 GB
# 11     REDMI Note 9 (Arctic White, 64 GB)  (4 GB RAM)     Arctic White  4 GB
# 12              Redmi 9 (Sky Blue, 64 GB)  (4 GB RAM)         Sky Blue  4 GB
# 13   REDMI 9 Power (Mighty Black, 128 GB)  (6 GB RAM)     Mighty Black  6 GB
# 14     REDMI Note 9 (Pebble Grey, 128 GB)  (4 GB RAM)      Pebble Grey  4 GB
# 15   REDMI 9 Power (Mighty Black, 128 GB)  (4 GB RAM)     Mighty Black  4 GB
# 16        ViVO Y20G (Purist Blue, 128 GB)  (6 GB RAM)      Purist Blue  6 GB
# 17   REDMI 9 Power (Blazing Blue, 128 GB)  (6 GB RAM)     Blazing Blue  6 GB
# 18         Redmi 9A (Nature Green, 32 GB)  (2 GB RAM)     Nature Green  2 GB
# 19              Redmi 9A (SeaBlue, 32 GB)  (2 GB RAM)          SeaBlue  2 GB
# 20     REDMI 9 Prime (Matte Black, 64 GB)  (4 GB RAM)      Matte Black  4 GB
# 21       Redmi 9A (Midnight Black, 32 GB)  (2 GB RAM)   Midnight Black  2 GB
# 22    REDMI Note 9 (Arctic White, 128 GB)  (4 GB RAM)     Arctic White  4 GB
# 23  Itel VISION1 (GRADATION GREEN, 32 GB)  (2 GB RAM)  GRADATION GREEN  2 GB
#
#        rom            displaysize   displayresolution           primarycamera  \
# 0   128 GB   14.76 cm (5.81 inch)  2340 x 1080 Pixels      12.2MP Rear Camera
# 1    64 GB   16.59 cm (6.53 inch)  2340 x 1080$$pixel        48MP Rear Camera
# 2    64 GB   16.59 cm (6.53 inch)  2340 x 1080$$pixel        48MP Rear Camera
# 3    64 GB   16.59 cm (6.53 inch)  2340 x 1080$$pixel        48MP Rear Camera
# 4    64 GB   16.59 cm (6.53 inch)  2340 x 1080$$pixel        48MP Rear Camera
# 5    64 GB   16.59 cm (6.53 inch)  2340 x 1080$$pixel        48MP Rear Camera
# 6    64 GB   16.59 cm (6.53 inch)  2340 x 1080$$pixel        48MP Rear Camera
# 7    64 GB   16.59 cm (6.53 inch)  2340 x 1080$$pixel        48MP Rear Camera
# 8   128 GB    16.26 cm (6.4 inch)  2340 x 1080$$pixel  64MP + 8MP + 5MP + 5MP
# 9    64 GB   16.59 cm (6.53 inch)   720 x 1600$$pixel              13MP + 8MP
# 10   64 GB   16.59 cm (6.53 inch)   720 x 1600$$pixel              13MP + 2MP
# 11   64 GB   16.59 cm (6.53 inch)  2340 x 1080$$pixel        48MP Rear Camera
# 12   64 GB   16.59 cm (6.53 inch)   720 x 1600$$pixel              13MP + 2MP
# 13  128 GB   16.59 cm (6.53 inch)  2340 x 1080$$pixel        48MP Rear Camera
# 14  128 GB   16.59 cm (6.53 inch)  2340 x 1080$$pixel        48MP Rear Camera
# 15  128 GB   16.59 cm (6.53 inch)  2340 x 1080$$pixel        48MP Rear Camera
# 16  128 GB   16.54 cm (6.51 inch)   1600 x 720$$pixel          Primary Camera
# 17  128 GB   16.59 cm (6.53 inch)  2340 x 1080$$pixel        48MP Rear Camera
# 18   32 GB   16.59 cm (6.53 inch)   720 x 1600$$pixel        13MP Rear Camera
# 19   32 GB   16.59 cm (6.53 inch)   720 x 1600$$pixel                       -
# 20   64 GB   16.59 cm (6.53 inch)  2340 x 1080 Pixels        13MP Rear Camera
# 21   32 GB   16.59 cm (6.53 inch)   720 x 1600$$pixel        13MP Rear Camera
# 22  128 GB   16.59 cm (6.53 inch)  2340 x 1080$$pixel        48MP Rear Camera
# 23   32 GB  15.46 cm (6.088 inch)   1560 x 720$$pixel         8MP Rear Camera
#
#           secondarycamera                   processor processorcore  \
# 0        8MP Front Camera    Qualcomm Snapdragon 730G     Octa Core
# 1        8MP Front Camera     Qualcomm Snapdragon 662     Octa Core
# 2        8MP Front Camera     Qualcomm Snapdragon 662     Octa Core
# 3   13MP AI Selfie Camera          MediaTek Helio G85     Octa Core
# 4        8MP Front Camera     Qualcomm Snapdragon 662     Octa Core
# 5        8MP Front Camera     Qualcomm Snapdragon 662     Octa Core
# 6   13MP AI Selfie Camera          MediaTek Helio G85     Octa Core
# 7   13MP AI Selfie Camera          MediaTek Helio G85     Octa Core
# 8       32MP Front Camera  Samsung Exynos 9 Octa 9611     Octa Core
# 9        5MP Front Camera          MediaTek Helio G35       2.3 GHz
# 10       5MP Front Camera          MediaTek Helio G35     Octa Core
# 11  13MP AI Selfie Camera          MediaTek Helio G85     Octa Core
# 12       5MP Front Camera          MediaTek Helio G35       2.3 GHz
# 13       8MP Front Camera   Qualcomm® Snapdragon™ 662     Octa Core
# 14  13MP AI Selfie Camera          MediaTek Helio G85     Octa Core
# 15       8MP Front Camera     Qualcomm Snapdragon 662     Octa Core
# 16                      -                   Octa Core         2 GHz
# 17       8MP Front Camera   Qualcomm® Snapdragon™ 662     Octa Core
# 18                    Yes                   Octa Core         2 GHz
# 19                      -                   Octa Core         2 GHz
# 20       8MP Front Camera          MediaTek Helio G80     Octa Core
# 21                    Yes                   Octa Core         2 MHz
# 22  13MP AI Selfie Camera          MediaTek Helio G85     Octa Core
# 23                    Yes    UNISOC SC9863A OCTA CORE     Octa Core
#
#                                               battery    price  \
# 0                                            3140 mAh  ₹31,999
# 1   MP3, FLAC, APE, DSF, M4A, AAC, OGG, WAV, WMA, ...   ₹9,999
# 2   MP3, FLAC, APE, DSF, M4A, AAC, OGG, WAV, WMA, ...   ₹9,999
# 3                                            5020 mAh  ₹10,999
# 4   MP3, FLAC, APE, DSF, M4A, AAC, OGG, WAV, WMA, ...   ₹9,999
# 5   MP3, FLAC, APE, DSF, M4A, AAC, OGG, WAV, WMA, ...   ₹9,999
# 6                                            5020 mAh  ₹10,999
# 7                                            5020 mAh  ₹10,999
# 8                                            6000 mAh  ₹15,901
# 9     PCM, AAC/AAC+/eAAC+, MP3, AMR-NB, WB, FLAC, APE   ₹8,934
# 10    PCM, AAC/AAC+/eAAC+, MP3, AMR-NB, WB, FLAC, APE   ₹8,985
# 11                                           5020 mAh  ₹10,999
# 12    PCM, AAC/AAC+/eAAC+, MP3, AMR-NB, WB, FLAC, APE   ₹8,907
# 13  MP3, FLAC, APE, DSF, M4A, AAC, OGG, WAV, WMA, ...  ₹12,999
# 14                                           5020 mAh  ₹12,999
# 15  MP3, FLAC, APE, DSF, M4A, AAC, OGG, WAV, WMA, ...  ₹11,999
# 16                                             1 year  ₹14,990
# 17  MP3, FLAC, APE, DSF, M4A, AAC, OGG, WAV, WMA, ...  ₹12,999
# 18                                           5000 mAh   ₹7,350
# 19                                           5000 mAh   ₹7,152
# 20  PCM, AAC / AAC+, MP3, AMR-NB and WB, PCM/WAVE ...   ₹9,999
# 21                                           5000 mAh   ₹7,079
# 22                                           5020 mAh  ₹12,999
# 23                                   MP3, AAC,AMR,MID   ₹6,699
#
#                                                   url
# 0   https://www.flipkart.com/google-pixel-4a-just-...
# 1   https://www.flipkart.com/redmi-9-power-electri...
# 2   https://www.flipkart.com/redmi-9-power-mighty-...
# 3   https://www.flipkart.com/redmi-note-9-pebble-g...
# 4   https://www.flipkart.com/redmi-9-power-blazing...
# 5   https://www.flipkart.com/redmi-9-power-fiery-r...
# 6   https://www.flipkart.com/redmi-note-9-shadow-b...
# 7   https://www.flipkart.com/redmi-note-9-aqua-gre...
# 8   https://www.flipkart.com/samsung-galaxy-m31-sp...
# 9   https://www.flipkart.com/redmi-9-sporty-orange...
# 10  https://www.flipkart.com/redmi-9-carbon-black-...
# 11  https://www.flipkart.com/redmi-note-9-arctic-w...
# 12  https://www.flipkart.com/redmi-9-sky-blue-64-g...
# 13  https://www.flipkart.com/redmi-9-power-mighty-...
# 14  https://www.flipkart.com/redmi-note-9-pebble-g...
# 15  https://www.flipkart.com/redmi-9-power-mighty-...
# 16  https://www.flipkart.com/vivo-y20g-purist-blue...
# 17  https://www.flipkart.com/redmi-9-power-blazing...
# 18  https://www.flipkart.com/redmi-9a-nature-green...
# 19  https://www.flipkart.com/redmi-9a-seablue-32-g...
# 20  https://www.flipkart.com/redmi-9-prime-matte-b...
# 21  https://www.flipkart.com/redmi-9a-midnight-bla...
# 22  https://www.flipkart.com/redmi-note-9-arctic-w...
# 23  https://www.flipkart.com/itel-vision1-gradatio...

# %%
df['smartphonename']=df['smartphonename'].apply(lambda x:x.split('(')[0])
df['primarycamera']=df['primarycamera'].apply(lambda x:x.split(' ')[0])
df['secondarycamera']=df['secondarycamera'].apply(lambda x:x.split(' ')[0])
df
# Out:
#          smartphonename            color   ram     rom            displaysize  \
# 0      Google Pixel 4a        Just Black  6 GB  128 GB   14.76 cm (5.81 inch)
# 1        REDMI 9 Power    Electric Green  4 GB   64 GB   16.59 cm (6.53 inch)
# 2        REDMI 9 Power      Mighty Black  4 GB   64 GB   16.59 cm (6.53 inch)
# 3         REDMI Note 9       Pebble Grey  4 GB   64 GB   16.59 cm (6.53 inch)
# 4        REDMI 9 Power      Blazing Blue  4 GB   64 GB   16.59 cm (6.53 inch)
# 5        REDMI 9 Power         Fiery Red  4 GB   64 GB   16.59 cm (6.53 inch)
# 6         REDMI Note 9      Shadow Black  4 GB   64 GB   16.59 cm (6.53 inch)
# 7         REDMI Note 9        Aqua Green  4 GB   64 GB   16.59 cm (6.53 inch)
# 8   SAMSUNG Galaxy M31       Space Black  6 GB  128 GB    16.26 cm (6.4 inch)
# 9              Redmi 9     Sporty Orange  4 GB   64 GB   16.59 cm (6.53 inch)
# 10             Redmi 9      Carbon Black  4 GB   64 GB   16.59 cm (6.53 inch)
# 11        REDMI Note 9      Arctic White  4 GB   64 GB   16.59 cm (6.53 inch)
# 12             Redmi 9          Sky Blue  4 GB   64 GB   16.59 cm (6.53 inch)
# 13       REDMI 9 Power      Mighty Black  6 GB  128 GB   16.59 cm (6.53 inch)
# 14        REDMI Note 9       Pebble Grey  4 GB  128 GB   16.59 cm (6.53 inch)
# 15       REDMI 9 Power      Mighty Black  4 GB  128 GB   16.59 cm (6.53 inch)
# 16           ViVO Y20G       Purist Blue  6 GB  128 GB   16.54 cm (6.51 inch)
# 17       REDMI 9 Power      Blazing Blue  6 GB  128 GB   16.59 cm (6.53 inch)
# 18            Redmi 9A      Nature Green  2 GB   32 GB   16.59 cm (6.53 inch)
# 19            Redmi 9A           SeaBlue  2 GB   32 GB   16.59 cm (6.53 inch)
# 20       REDMI 9 Prime       Matte Black  4 GB   64 GB   16.59 cm (6.53 inch)
# 21            Redmi 9A    Midnight Black  2 GB   32 GB   16.59 cm (6.53 inch)
# 22        REDMI Note 9      Arctic White  4 GB  128 GB   16.59 cm (6.53 inch)
# 23        Itel VISION1   GRADATION GREEN  2 GB   32 GB  15.46 cm (6.088 inch)
#
#      displayresolution primarycamera secondarycamera  \
# 0   2340 x 1080 Pixels        12.2MP             8MP
# 1   2340 x 1080$$pixel          48MP             8MP
# 2   2340 x 1080$$pixel          48MP             8MP
# 3   2340 x 1080$$pixel          48MP            13MP
# 4   2340 x 1080$$pixel          48MP             8MP
# 5   2340 x 1080$$pixel          48MP             8MP
# 6   2340 x 1080$$pixel          48MP            13MP
# 7   2340 x 1080$$pixel          48MP            13MP
# 8   2340 x 1080$$pixel          64MP            32MP
# 9    720 x 1600$$pixel          13MP             5MP
# 10   720 x 1600$$pixel          13MP             5MP
# 11  2340 x 1080$$pixel          48MP            13MP
# 12   720 x 1600$$pixel          13MP             5MP
# 13  2340 x 1080$$pixel          48MP             8MP
# 14  2340 x 1080$$pixel          48MP            13MP
# 15  2340 x 1080$$pixel          48MP             8MP
# 16   1600 x 720$$pixel       Primary               -
# 17  2340 x 1080$$pixel          48MP             8MP
# 18   720 x 1600$$pixel          13MP             Yes
# 19   720 x 1600$$pixel             -               -
# 20  2340 x 1080 Pixels          13MP             8MP
# 21   720 x 1600$$pixel          13MP             Yes
# 22  2340 x 1080$$pixel          48MP            13MP
# 23   1560 x 720$$pixel           8MP             Yes
#
#                      processor processorcore  \
# 0     Qualcomm Snapdragon 730G     Octa Core
# 1      Qualcomm Snapdragon 662     Octa Core
# 2      Qualcomm Snapdragon 662     Octa Core
# 3           MediaTek Helio G85     Octa Core
# 4      Qualcomm Snapdragon 662     Octa Core
# 5      Qualcomm Snapdragon 662     Octa Core
# 6           MediaTek Helio G85     Octa Core
# 7           MediaTek Helio G85     Octa Core
# 8   Samsung Exynos 9 Octa 9611     Octa Core
# 9           MediaTek Helio G35       2.3 GHz
# 10          MediaTek Helio G35     Octa Core
# 11          MediaTek Helio G85     Octa Core
# 12          MediaTek Helio G35       2.3 GHz
# 13   Qualcomm® Snapdragon™ 662     Octa Core
# 14          MediaTek Helio G85     Octa Core
# 15     Qualcomm Snapdragon 662     Octa Core
# 16                   Octa Core         2 GHz
# 17   Qualcomm® Snapdragon™ 662     Octa Core
# 18                   Octa Core         2 GHz
# 19                   Octa Core         2 GHz
# 20          MediaTek Helio G80     Octa Core
# 21                   Octa Core         2 MHz
# 22          MediaTek Helio G85     Octa Core
# 23    UNISOC SC9863A OCTA CORE     Octa Core
#
#                                               battery    price  \
# 0                                            3140 mAh  ₹31,999
# 1   MP3, FLAC, APE, DSF, M4A, AAC, OGG, WAV, WMA, ...   ₹9,999
# 2   MP3, FLAC, APE, DSF, M4A, AAC, OGG, WAV, WMA, ...   ₹9,999
# 3                                            5020 mAh  ₹10,999
# 4   MP3, FLAC, APE, DSF, M4A, AAC, OGG, WAV, WMA, ...   ₹9,999
# 5   MP3, FLAC, APE, DSF, M4A, AAC, OGG, WAV, WMA, ...   ₹9,999
# 6                                            5020 mAh  ₹10,999
# 7                                            5020 mAh  ₹10,999
# 8                                            6000 mAh  ₹15,901
# 9     PCM, AAC/AAC+/eAAC+, MP3, AMR-NB, WB, FLAC, APE   ₹8,934
# 10    PCM, AAC/AAC+/eAAC+, MP3, AMR-NB, WB, FLAC, APE   ₹8,985
# 11                                           5020 mAh  ₹10,999
# 12    PCM, AAC/AAC+/eAAC+, MP3, AMR-NB, WB, FLAC, APE   ₹8,907
# 13  MP3, FLAC, APE, DSF, M4A, AAC, OGG, WAV, WMA, ...  ₹12,999
# 14                                           5020 mAh  ₹12,999
# 15  MP3, FLAC, APE, DSF, M4A, AAC, OGG, WAV, WMA, ...  ₹11,999
# 16                                             1 year  ₹14,990
# 17  MP3, FLAC, APE, DSF, M4A, AAC, OGG, WAV, WMA, ...  ₹12,999
# 18                                           5000 mAh   ₹7,350
# 19                                           5000 mAh   ₹7,152
# 20  PCM, AAC / AAC+, MP3, AMR-NB and WB, PCM/WAVE ...   ₹9,999
# 21                                           5000 mAh   ₹7,079
# 22                                           5020 mAh  ₹12,999
# 23                                   MP3, AAC,AMR,MID   ₹6,699
#
#                                                   url
# 0   https://www.flipkart.com/google-pixel-4a-just-...
# 1   https://www.flipkart.com/redmi-9-power-electri...
# 2   https://www.flipkart.com/redmi-9-power-mighty-...
# 3   https://www.flipkart.com/redmi-note-9-pebble-g...
# 4   https://www.flipkart.com/redmi-9-power-blazing...
# 5   https://www.flipkart.com/redmi-9-power-fiery-r...
# 6   https://www.flipkart.com/redmi-note-9-shadow-b...
# 7   https://www.flipkart.com/redmi-note-9-aqua-gre...
# 8   https://www.flipkart.com/samsung-galaxy-m31-sp...
# 9   https://www.flipkart.com/redmi-9-sporty-orange...
# 10  https://www.flipkart.com/redmi-9-carbon-black-...
# 11  https://www.flipkart.com/redmi-note-9-arctic-w...
# 12  https://www.flipkart.com/redmi-9-sky-blue-64-g...
# 13  https://www.flipkart.com/redmi-9-power-mighty-...
# 14  https://www.flipkart.com/redmi-note-9-pebble-g...
# 15  https://www.flipkart.com/redmi-9-power-mighty-...
# 16  https://www.flipkart.com/vivo-y20g-purist-blue...
# 17  https://www.flipkart.com/redmi-9-power-blazing...
# 18  https://www.flipkart.com/redmi-9a-nature-green...
# 19  https://www.flipkart.com/redmi-9a-seablue-32-g...
# 20  https://www.flipkart.com/redmi-9-prime-matte-b...
# 21  https://www.flipkart.com/redmi-9a-midnight-bla...
# 22  https://www.flipkart.com/redmi-note-9-arctic-w...
# 23  https://www.flipkart.com/itel-vision1-gradatio...

# %% [markdown]
# 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on
# google maps.

# %%
import selenium
import time
from selenium import webdriver

# %%
driver=webdriver.Chrome(r'chromedriver.exe')
driver.get("https://www.google.com/maps")
time.sleep(5)
location=driver.find_element_by_xpath("//input[@class='tactile-searchbox-input']")
input1=input("enter location:")
location.send_keys(input1)
time.sleep(5)
driver.find_element_by_id("searchbox-searchbutton").click()
time.sleep(5)
url=driver.current_url
x=url.split('@')[-1]
x=x.split('/')[0]
lat=x.split(',')[0]
long=x.split(',')[1]
print("Latitude:",lat,"Longitude:",long)
# Out:
# enter location:chennai
# Latitude: 13.0473748 Longitude: 79.9288011

# %% [markdown]
# 6. Write a program to scrap details of all the funding deals for second quarter (i.e. July 20 –
# September 20) from trak.in.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url='https://trak.in/india-startup-funding-investment-2015/'
page=requests.get(url)
soup=BeautifulSoup(page.content)

# %%
Date=[]
Startup=[]
Industry=[]
Subvertical=[]
City=[]
Investor=[]
Investment=[]
Amount=[]
for p in soup.find_all("td",class_='column-2'):
    Date.append(p.text)
for s in soup.find_all("td",class_='column-3'):
    Startup.append(s.text)
for o in soup.find_all("td",class_='column-4'):
    Industry.append(o.text)
for i in soup.find_all("td",class_='column-5'):
    Subvertical.append(i.text)
for j in soup.find_all("td",class_='column-6'):
    City.append(j.text)
for k in soup.find_all("td",class_='column-7'):
    Investor.append(k.text)
for l in soup.find_all("td",class_='column-8'):
    Investment.append(l.text)
for m in soup.find_all("td",class_='column-9'):
    Amount.append(m.text)

# %%
df=pd.DataFrame({})
df['Date']=Date
df['StartUp']=Startup
df['Industry']=Industry
df['Subvertical']=Subvertical
df['City']=City
df['Investor']=Investor
df['Investment Type']=Investment
df['Amount']=Amount
df
# Out:
#            Date          StartUp              Industry  \
# 0    01/04/2021           BYJU’S              Edu-tech
# 1    05/04/2021           Meesho            E-commerce
# 2    14/04/2021           Swiggy  Online Food Delivery
# 3    07/04/2021            Groww               FinTech
# 4    14/04/2021          Beldara            E-commerce
# ..          ...              ...                   ...
# 611  26/07/2018    TheCapitalNet              Fin-Tech
# 612  30/07/2018           Shuttl     Consumer Internet
# 613  30/07/2018         Cure Fit     Consumer Internet
# 614  31/07/2018  Five Star Group              Fin-Tech
# 615  31/07/2018      Healthsignz            Healthcare
#
#                               Subvertical       City  \
# 0                         Online tutoring  Bengaluru
# 1               Online reselling platform  Bengaluru
# 2                    Online Food Delivery  Bengaluru
# 3                     Investment platform  Bengaluru
# 4                  Global B2B marketplace     Mumbai
# ..                                    ...        ...
# 611  Unified Global Investments Ecosystem  Hyderabad
# 612              Bus Aggregation Platform   Gurugram
# 613           Health and fitness Platform  Bengaluru
# 614     Non-Bank Lending Platform For SME    Chennai
# 615        Health and Well being Platform  Hyderabad
#
#                                               Investor      Investment Type  \
# 0                                      Innoven Capital             Series F
# 1                               SoftBank Vision Fund 2             Series E
# 2    Amansa Holdings, Carmignac, Falcon Edge Capita...             Series J
# 3           MC Global Edtech, B Capital, Baron, others             Series D
# 4                             Hindustan Media Ventures              Venture
# ..                                                 ...                  ...
# 611              Lindwall Family Investments LLC (LFI)       Private Equity
# 612                Amazon Alexa Fund & Dentsu Ventures       Private Equity
# 613  IDG Ventures, Accel Partners, Kalaari Capital ...       Private Equity
# 614  TPG, Norwest Venture Partners, Sequoia Capital...       Private Equity
# 615                                     Kantilal Patel  Seed/ Angel Funding
#
#           Amount
# 0    460,000,000
# 1    300,000,000
# 2    343,000,000
# 3     83,000,000
# 4      7,400,000
# ..           ...
# 611      500,000
# 612  1,10,00,000
# 613  120,000,000
# 614  100,000,000
# 615    5,000,000
#
# [616 rows x 8 columns]

# %%
df=df.loc[57:89]
df
# Out:
#           Date                    StartUp  \
# 57  08/09/2020                     Byju’s
# 58  12/09/2020                  mCaffeine
# 59  09/09/2020                     Qshala
# 60  02/09/2020                      Winzo
# 61  09/09/2020                Hippo Video
# 62  07/09/2020                    Melorra
# 63  07/09/2020                        1mg
# 64  31/08/2020                      mfine
# 65  31/08/2020                       Apna
# 66  03/09/2020                    Railofy
# 67  08/09/2020            Cell Propulsion
# 68  15/08/2020                     Practo
# 69  13/08/2020                    Medlife
# 70  13/08/2020                HungerBox\n
# 71  04/08/2020                      Dunzo
# 72  11/08/2020                   Terra.do
# 73  12/08/2020                  Classplus
# 74  14/08/2020                       Niyo
# 75  10/08/2020                  ZestMoney
# 76  07/08/2020                FreshToHome
# 77  13/08/2020                    Eduvanz
# 78  03/08/2020                 CrowdPouch
# 79  04/08/2020                 DrinkPrime
# 80  15/07/2020                   Flipkart
# 81  16/07/2020                    Vedantu
# 82  16/07/2020                       Crio
# 83  14/07/2020                    goDutch
# 84  13/07/2020                 Mystifly\n
# 85  09/07/2020               JetSynthesys
# 86  10/07/2020                 gigIndia\n
# 87  15/07/2020                  PumPumPum
# 88  14/07/2020                       FLYX
# 89  13/07/2020  Open Appliances Pvt. Ltd.
#
#                                   Industry  \
# 57                                 EduTech
# 58                           Personal Care
# 59                                 EduTech
# 60                           Online Gaming
# 61  Video Customer Experience(CX) Platform
# 62                              E-commerce
# 63                              E-commerce
# 64                              HealthTech
# 65                         Human Resources
# 66                          Transportation
# 67                              Automobile
# 68                              HealthTech
# 69                              E-commerce
# 70                                FoodTech
# 71                   Hyper-local Logistics
# 72                                 EduTech
# 73                                 EduTech
# 74                                 FinTech
# 75                                 FinTech
# 76                              E-commerce
# 77                                 FinTech
# 78                                 FinTech
# 79                      Water Purification
# 80                              E-commerce
# 81                                 EduTech
# 82                                 EduTech
# 83                                 FinTech
# 84                     Airfare Marketplace
# 85                Gaming and Entertainment
# 86                             Marketplace
# 87                       Automotive Rental
# 88                              OTT Player
# 89                  Information Technology
#
#                                           Subvertical  \
# 57                                    Online Tutoring
# 58                                Skincare & Haircare
# 59                 Online Curiosity Platform for Kids
# 60                                      Online Gaming
# 61             Video Customer Experience(CX) Platform
# 62                             Online Jewelry Store\n
# 63                                    Online Pharmacy
# 64                      On-Demand Healthcare Services
# 65                               Recruitment Platform
# 66                       WL & RAC protection platform
# 67                        Electric Mobility Solutions
# 68                           Health care and Wellness
# 69                                    Online Pharmacy
# 70                       Online Food Delivery Service
# 71                           Online Delivery Services
# 72                  Online Climate School, E-learning
# 73                    E-learning, Online Tutoring\n\n
# 74                                 Financial Services
# 75                                 Financial Services
# 76                                      Food Delivery
# 77                                 Financial Services
# 78                                 Financial Services
# 79                                 Water Purification
# 80                                         E-commerce
# 81                                    Online Tutoring
# 82                   Learning Platform for Developers
# 83                                     Group Payments
# 84   Ticketing, Airline Retailing, and Post-Ticket...
# 85                       Gaming and Entertainment\n\n
# 86                          Crowd Sourcing, Freelance
# 87                          Used Car-leasing platform
# 88                           Streaming Social Network
# 89              Internet-of-Things Security Solutions
#
#                                           City  \
# 57                                   Bangalore
# 58                                      Mumbai
# 59                                   Bangalore
# 60                                   New Delhi
# 61  Newark, Delaware, United States of Amercia
# 62                                   Bangalore
# 63                                     Gurgaon
# 64                                   Bangalore
# 65                                   Bangalore
# 66                                      Mumbai
# 67                                   Bangalore
# 68                                   Bangalore
# 69                                   Bangalore
# 70                                   Bangalore
# 71                                   Bangalore
# 72                      Stanford, California,
# 73                                       Noida
# 74                                   Bangalore
# 75                                   Bangalore
# 76                                   Bangalore
# 77                                      Mumbai
# 78                                   Bangalore
# 79                                   Bangalore
# 80                                   Bangalore
# 81                                   Bangalore
# 82                                   Bangalore
# 83                                      Mumbai
# 84                     Singapore and Bangalore
# 85                                        Pune
# 86                                        Pune
# 87                                     Gurgaon
# 88                          New York and Delhi
# 89                                   Bangalore
#
#                                              Investor         Investment Type  \
# 57  Silver Lake, Tiger Global, General Atlantic an...          Private Equity
# 58  Amicus Capital Private Equity I LLP, Amicus Ca...                Series B
# 59                                 Rainmatter Capital                   Angel
# 60  Kalaari Capital Partners, IndigoEdge Managemen...                Series B
# 61  Alpha Wave Incubation, Exfinity Venture Partne...                Series A
# 62                         Shadow Holdings, Lightbox.          Debt Financing
# 63         Gaja Capital, Tata Capital, Partners Group             In Progress
# 64                                   Caretech Pte Inc                Series B
# 65         Lightspeed India and Sequoia Capital India                Series A
# 66                                  Chiratae Ventures                    Seed
# 67                         growX Ventures and Micelio            pre-Series A
# 68                                      A1A Company\n                Series F
# 69         Prasid Uno Family Trust and SC Credit Fund
# 70  One97, Sabre Partners Trust, Pratithi Investme...               Series D1
# 71                                   Existing Backers             In Progress
# 72  Stanford Angels and Entrepreneurs (India), BEE...                    Seed
# 73                                        Falcon Edge             In Progress
# 74                                Niyo Solutions Inc.
# 75                            Primrose Hills Ventures
# 76                                     Ascent Capital                Venture
# 77                              Sequoia India, Unitus                Series A
# 78                         Elina Investments Pvt. Ltd                   Angel
# 79                        Sequoia Surge, ON Mauritius            Pre-Series A
# 80                                      Walmart Inc\n                     M&A
# 81                                  Coatue Management                Series D
# 82                                        021 Capital            pre-Series A
# 83  Matrix India,Y Combinator, Global Founders Cap...                    Seed
# 84                               Recruit Co. Ltd.\n\n            pre-Series B
# 85         Adar Poonawalla and Kris Gopalakrishnan.\n  Venture-Series Unknown
# 86       Incubate Fund India and Beyond Next Ventures            pre-Series A
# 87                           Early Adapters Syndicate                    Seed
# 88              Raj Mishra, founder of AIT Global Inc                pre-Seed
# 89                             Unicorn India Ventures  Venture-Series Unknown
#
#              Amount
# 57      500,000,000
# 58      3,000,000\n
# 59          370,000
# 60       15,500,000
# 61        4,500,000
# 62   upto 8,900,000
# 63      100,000,000
# 64        5,400,000
# 65       8,000,000
# 66          950,000
# 67               NA
# 68       32,000,000
# 69     23,000,000\n
# 70        1,560,000
# 71       30,000,000
# 72        1,400,000
# 73  upto 15,000,000
# 74        6,000,000
# 75       10,670,000
# 76      16,200,000
# 77        5,000,000
# 78               NA
# 79        2,880,000
# 80    1,200,000,000
# 81    100,000,000\n
# 82          934,160
# 83        1,700,000
# 84        3,300,000
# 85          400,000
# 86          974,200
# 87          292,800
# 88         200,000
# 89          500,000

# %% [markdown]
# using selenium

# %%
import selenium
import time
from selenium import webdriver
driver=webdriver.Chrome(r'chromedriver.exe')
driver.get("https://www.trak.in/")
time.sleep(3)

# %%
x=driver.find_element_by_xpath("//li[@class='menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-post_type menu-item-object-page better-anim-fade menu-item-51510']/a")
y=x.get_attribute("href")
driver.get(y)#taking website url to funding dea

# %%
Date=[]
Startup=[]
Industry=[]
Subvertical=[]
City=[]
Investor=[]
Investment=[]
Amount=[]
for i in driver.find_elements_by_xpath("//td[@class='column-2']"):
    Date.append(i.text)
for j in driver.find_elements_by_xpath("//td[@class='column-3']"):
    Startup.append(j.text)
for k in driver.find_elements_by_xpath("//td[@class='column-4']"):
    Industry.append(k.text)
for l in driver.find_elements_by_xpath("//td[@class='column-5']"):
    Subvertical.append(l.text)
for m in driver.find_elements_by_xpath("//td[@class='column-6']"):
    City.append(m.text)
for n in driver.find_elements_by_xpath("//td[@class='column-7']"):
    Investor.append(n.text)
for o in driver.find_elements_by_xpath("//td[@class='column-8']"):
    Investment.append(o.text)
for p in driver.find_elements_by_xpath("//td[@class='column-9']"):
    Amount.append(p.text)

# %%
#making dataframe 
import pandas as pd
df=pd.DataFrame({})
df['Date']=Date
df['StartUp']=Startup
df['Industry']=Industry
df['Subvertical']=Subvertical
df['City']=City
df['Investor']=Investor
df['Investment Type']=Investment
df['Amount']=Amount
df=df.loc[57:89]
df
# Out:
#           Date                    StartUp  \
# 57  09/09/2020                     Qshala
# 58  02/09/2020                      Winzo
# 59  09/09/2020                Hippo Video
# 60  07/09/2020                    Melorra
# 61  07/09/2020                        1mg
# 62  31/08/2020                      mfine
# 63  31/08/2020                       Apna
# 64  03/09/2020                    Railofy
# 65  15/08/2020                     Practo
# 66  13/08/2020                    Medlife
# 67  13/08/2020                  HungerBox
# 68  04/08/2020                      Dunzo
# 69  11/08/2020                   Terra.do
# 70  12/08/2020                  Classplus
# 71  14/08/2020                       Niyo
# 72  10/08/2020                  ZestMoney
# 73  07/08/2020                FreshToHome
# 74  13/08/2020                    Eduvanz
# 75  15/07/2020                   Flipkart
# 76  16/07/2020                    Vedantu
# 77  16/07/2020                       Crio
# 78  14/07/2020                    goDutch
# 79  13/07/2020                   Mystifly
# 80  09/07/2020               JetSynthesys
# 81  10/07/2020                   gigIndia
# 82  15/07/2020                  PumPumPum
# 83  14/07/2020                       FLYX
# 84  13/07/2020  Open Appliances Pvt. Ltd.
# 85  18/06/2020       Drishti Technologies
# 86  17/06/2020                   Stellaps
# 87  17/06/2020                 Peppermint
# 88  16/06/2020                  Jai Kisan
# 89  16/06/2020                  Biomoneta
#
#                                   Industry  \
# 57                                 EduTech
# 58                           Online Gaming
# 59  Video Customer Experience(CX) Platform
# 60                              E-commerce
# 61                              E-commerce
# 62                              HealthTech
# 63                         Human Resources
# 64                          Transportation
# 65                              HealthTech
# 66                              E-commerce
# 67                                FoodTech
# 68                   Hyper-local Logistics
# 69                                 EduTech
# 70                                 EduTech
# 71                                 FinTech
# 72                                 FinTech
# 73                              E-commerce
# 74                                 FinTech
# 75                              E-commerce
# 76                                 EduTech
# 77                                 EduTech
# 78                                 FinTech
# 79                     Airfare Marketplace
# 80                Gaming and Entertainment
# 81                             Marketplace
# 82                       Automotive Rental
# 83                              OTT Player
# 84                  Information Technology
# 85                              Technology
# 86                                AgriTech
# 87                     Industrial Robotics
# 88                           Rural FinTech
# 89                                 BioTech
#
#                                           Subvertical  \
# 57                 Online Curiosity Platform for Kids
# 58                                      Online Gaming
# 59             Video Customer Experience(CX) Platform
# 60                               Online Jewelry Store
# 61                                    Online Pharmacy
# 62                      On-Demand Healthcare Services
# 63                               Recruitment Platform
# 64                       WL & RAC protection platform
# 65                           Health care and Wellness
# 66                                    Online Pharmacy
# 67                       Online Food Delivery Service
# 68                           Online Delivery Services
# 69                  Online Climate School, E-learning
# 70                        E-learning, Online Tutoring
# 71                                 Financial Services
# 72                                 Financial Services
# 73                                      Food Delivery
# 74                                 Financial Services
# 75                                         E-commerce
# 76                                    Online Tutoring
# 77                   Learning Platform for Developers
# 78                                     Group Payments
# 79  Ticketing, Airline Retailing, and Post-Ticketi...
# 80                           Gaming and Entertainment
# 81                          Crowd Sourcing, Freelance
# 82                          Used Car-leasing platform
# 83                           Streaming Social Network
# 84              Internet-of-Things Security Solutions
# 85           Artificial Intelligence, Video Analytics
# 86                     Farming, Dairy Management Apps
# 87                                Industrial Robotics
# 88                       AgriTech, Financial Services
# 89                 HealthTech, Biotechnology Research
#
#                                           City  \
# 57                                   Bangalore
# 58                                   New Delhi
# 59  Newark, Delaware, United States of Amercia
# 60                                   Bangalore
# 61                                     Gurgaon
# 62                                   Bangalore
# 63                                   Bangalore
# 64                                      Mumbai
# 65                                   Bangalore
# 66                                   Bangalore
# 67                                   Bangalore
# 68                                   Bangalore
# 69                       Stanford, California,
# 70                                       Noida
# 71                                   Bangalore
# 72                                   Bangalore
# 73                                   Bangalore
# 74                                      Mumbai
# 75                                   Bangalore
# 76                                   Bangalore
# 77                                   Bangalore
# 78                                      Mumbai
# 79                     Singapore and Bangalore
# 80                                        Pune
# 81                                        Pune
# 82                                     Gurgaon
# 83                          New York and Delhi
# 84                                   Bangalore
# 85                                      Mumbai
# 86                                   Bangalore
# 87                                      Mumbai
# 88                                      Mumbai
# 89                                   Bangalore
#
#                                              Investor         Investment Type  \
# 57                                 Rainmatter Capital                   Angel
# 58  Kalaari Capital Partners, IndigoEdge Managemen...                Series B
# 59  Alpha Wave Incubation, Exfinity Venture Partne...                Series A
# 60                         Shadow Holdings, Lightbox.          Debt Financing
# 61         Gaja Capital, Tata Capital, Partners Group             In Progress
# 62                                   Caretech Pte Inc                Series B
# 63         Lightspeed India and Sequoia Capital India                Series A
# 64                                  Chiratae Ventures                    Seed
# 65                                        A1A Company                Series F
# 66         Prasid Uno Family Trust and SC Credit Fund
# 67  One97, Sabre Partners Trust, Pratithi Investme...               Series D1
# 68                                   Existing Backers             In Progress
# 69  Stanford Angels and Entrepreneurs (India), BEE...                    Seed
# 70                                        Falcon Edge             In Progress
# 71                                Niyo Solutions Inc.
# 72                            Primrose Hills Ventures
# 73                                     Ascent Capital                 Venture
# 74                              Sequoia India, Unitus                Series A
# 75                                        Walmart Inc                     M&A
# 76                                  Coatue Management                Series D
# 77                                        021 Capital            pre-Series A
# 78  Matrix India,Y Combinator, Global Founders Cap...                    Seed
# 79                                   Recruit Co. Ltd.            pre-Series B
# 80           Adar Poonawalla and Kris Gopalakrishnan.  Venture-Series Unknown
# 81       Incubate Fund India and Beyond Next Ventures            pre-Series A
# 82                           Early Adapters Syndicate                    Seed
# 83              Raj Mishra, founder of AIT Global Inc                pre-Seed
# 84                             Unicorn India Ventures  Venture-Series Unknown
# 85                                      Sozo Ventures                Series B
# 86                                    Stride Ventures          Debt Financing
# 87             Venture Catalysts and Naveen Kshatriya                    Seed
# 88              Arkam Ventures and NABVENTURES Fund I            Pre-Series A
# 89  Beyond Next Ventures, ArthaVida Ventures and D...                    Seed
#
#              Amount
# 57          370,000
# 58       15,500,000
# 59        4,500,000
# 60   upto 8,900,000
# 61      100,000,000
# 62        5,400,000
# 63        8,000,000
# 64          950,000
# 65       32,000,000
# 66       23,000,000
# 67        1,560,000
# 68       30,000,000
# 69        1,400,000
# 70  upto 15,000,000
# 71        6,000,000
# 72       10,670,000
# 73       16,200,000
# 74        5,000,000
# 75    1,200,000,000
# 76      100,000,000
# 77          934,160
# 78        1,700,000
# 79        3,300,000
# 80          400,000
# 81          974,200
# 82          292,800
# 83          200,000
# 84          500,000
# 85       25,000,000
# 86               NA
# 87               NA
# 88        3,934,941
# 89               NA

# %% [markdown]
# 7. Write a program to scrap all the available details of top 10 gaming laptops from digit.in.

# %%
import selenium
import time
from selenium import webdriver
driver=webdriver.Chrome(r'chromedriver.exe')
driver.get("https://www.digit.in/")

# %%
#taking url to top 10 gaming laptops
driver.find_element_by_xpath("//div[@class='listing_container']/ul/li[9]/a").click()

# %%
driver.find_element_by_xpath("//div[@class='Listbrand']/ul/li[2]/a").click()

# %%
urls=[]
for i in driver.find_elements_by_xpath("//div[@class='right-container']/div/a"):
    urls.append(i.get_attribute("href"))

# %%
from selenium.common.exceptions import NoSuchElementException

# %%
laptopname=[]
releasedate=[]
os=[]
display=[]
processor=[]
memory=[]
price=[]
for i in urls:
    driver.get(i)
    time.sleep(5)
    try:
        laptopname.append(driver.find_element_by_xpath("//div[@class='heading-wraper']/h1").text)
    except NoSuchElementException:
        laptopname.append('-')
    try:
        releasedate.append(driver.find_element_by_xpath("//div[@class='status-bar only-desktop']/div[2]/b").text)
    except NoSuchElementException:
        releasedate.append('-')
    try:
        os.append(driver.find_element_by_xpath("//div[@class='value']").text)
    except NoSuchElementException:
        os.append('-')
    try:
        display.append(driver.find_element_by_xpath("//div[@class='Specs-Wrap  notspecs ']/ul/li[2]/div").text)
    except NoSuchElementException:
        display.append('-')
    try:
        processor.append(driver.find_element_by_xpath("//div[@class='Specs-Wrap  notspecs ']/ul/li[3]/div").text)
    except NoSuchElementException:
        processor.append('-')
    try:
        memory.append(driver.find_element_by_xpath("//div[@class='Specs-Wrap  notspecs ']/ul/li[4]/div").text)
    except NoSuchElementException:
        memory.append('-')
    try:
        price.append(driver.find_element_by_xpath("//div[@class='Block-price']/b").text)
    except NoSuchElementException:
        price.append('-')

# %%
import pandas as pd
df=pd.DataFrame({})
df['laptopname']=laptopname
df['releasedate']=releasedate
df['os']=os
df['display']=display
df['processor']=processor
df['memory']=memory
df['price']=price

# %%
df
# Out:
#                        laptopname   releasedate               os  \
# 0     Acer Aspire 7 A715-75G-50SA  19 Jun, 2020       Windows 10
# 1         MSI GF63 Thin 9SC-240IN  19 Jun, 2020       Windows 10
# 2         HP Pavillion 15-Bc512TX  19 Jun, 2020       Windows 10
# 3      Acer Nitro 5 AN517-51-53JG  19 Jun, 2020       Windows 10
# 4  Lenovo Legion Y7000 81V4000LIN  19 Jun, 2020       Windows 10
# 5  ASUS TUF Gaming FX505DD-AL185T  19 Jun, 2020       Windows 10
# 6  HP Pavilion Gaming 15-Ec0026AX  19 Jun, 2020       Windows 10
# 7  ASUS TUF Gaming FX505DY-BQ024T  19 Jun, 2020       Windows 10
# 8  Mi NoteBook 14 Horizon Edition  11 Jun, 2020  Windows 10 Home
# 9       Asus VivoBook 14 (X412FJ)  05 Jun, 2019  Windows 10 Home
#
#                display                                          processor  \
# 0  15.6" (1920 X 1080)  Core I5 9th Gen | 2.4 GHz With Turbo Boost Upt...
# 1  15.6" (1920 X 1080)  Core I5 9th Gen | 2.4 GHz With Turbo Boost Upt...
# 2  15.6" (1920 X 1080)                         9th Gen Intel Core I5 | NA
# 3  17.3" (1920 X 1080)                          Core I5 9th Gen | 2.4 GHz
# 4  15.6" (1920 X 1080)                    9th Gen Intel Core I5 | 2.4 Ghz
# 5  15.6" (1920 X 1080)                                                 NA
# 6  15.6" (1920 X 1080)                                                 NA
# 7  15.6" (1920 X 1080)                         AMD Ryzen 5-3550H | 2.1GHz
# 8    14" (1920 X 1080)           10th Generation Intel® Core™ I7 | 1.8GHz
# 9    14" (1920 X 1080)                         Intel 8th Gen Core I5 | NA
#
#                   memory   price
# 0     512 NA/8 GBGB DDR4  54,990
# 1  512 GB NA/8 GBGB DDR4  59,990
# 2  512 GB NA/8 GBGB DDR4  73,719
# 3    1 TB NA/8 GBGB DDR4  59,990
# 4    1 GB NA/8 GBGB DDR4  53,990
# 5    1 TB NA/8 GBGB DDR4  57,990
# 6    1 TB NA/8 GBGB DDR4  62,479
# 7   512GB NA/8 GBGB DDR4  54,990
# 8    512 GB SSD/8GB DDR4  59,999
# 9    512 GB SSD/8GB DDR4  55,990
